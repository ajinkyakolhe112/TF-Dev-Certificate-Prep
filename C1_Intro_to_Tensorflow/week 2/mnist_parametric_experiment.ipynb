# %%
import tensorflow as tf
import tensorflow.keras as keras
import datetime

(x_train_images, y_train_labels) , _ = keras.datasets.mnist.load_data() # _ is general throwaway variable. Not wasting characters to save something and dilute visual
x_train_images = x_train_images/255.0
y_train_labels = keras.utils.to_categorical(y_train_labels,10)

# %%
log_dir = "logs/train-" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
vis_callback = keras.callbacks.TensorBoard(log_dir, histogram_freq=1)

model = keras.models.Sequential([
    keras.layers.Input(shape=(28,28)),
    keras.layers.Flatten(),
    keras.layers.Dense(15,activation="relu", use_bias=False),
    keras.layers.Dense(10,activation="softmax", use_bias=False),
])
model.compile(
    loss = "categorical_crossentropy",
    optimizer= "sgd",
    metrics = ['accuracy'],
)
model.build(input_shape=(784))
print(model.summary())
model.fit(x_train_images, y_train_labels, epochs = 20, callbacks = [vis_callback])
# Out:
# Model: "sequential_41"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_37 (Flatten)        (None, 784)               0
#
#  dense_76 (Dense)            (None, 15)                11760
#
#  dense_77 (Dense)            (None, 10)                150
#
# ...
# Total params: 11,910
# Trainable params: 11,910
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 1875/1875 [==============================] - 1s 434us/step - loss: 0.8372 - accuracy: 0.7708
# Epoch 2/20
# 1875/1875 [==============================] - 1s 423us/step - loss: 0.3758 - accuracy: 0.8965
# Epoch 3/20
# 1875/1875 [==============================] - 1s 428us/step - loss: 0.3274 - accuracy: 0.9069
# Epoch 4/20
# 1875/1875 [==============================] - 1s 430us/step - loss: 0.3025 - accuracy: 0.9141
# Epoch 5/20
# ...

# %%
aim = "underfitting"
log_dir = "logs/" + aim + "/train-" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
vis_callback = keras.callbacks.TensorBoard(log_dir, histogram_freq=1)

model = keras.models.Sequential([
    keras.layers.Input(shape=(28,28,1)),
    keras.layers.Conv2D(10,7,activation="relu"),
    # keras.layers.Conv2D(10,7,activation= "relu"),
    keras.layers.Conv2D(10,7,activation= "relu"),
    keras.layers.Conv2D(10,7,activation= "relu"),

    keras.layers.Conv2D(10,3,activation="relu"),
    keras.layers.Conv2D(10,1,activation="relu"),
    keras.layers.Conv2D(10,1),
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Activation("softmax")
])
model.compile(
    loss = keras.losses.CategoricalCrossentropy(),
    optimizer= keras.optimizers.SGD(),
    metrics = ['accuracy'],
)
model.build(input_shape=(784))
print(model.summary())
model.fit(x_train_images, y_train_labels, epochs = 5, callbacks = [vis_callback])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_49 (Conv2D)          (None, 22, 22, 10)        500
#
#  conv2d_50 (Conv2D)          (None, 16, 16, 10)        4910
#
#  conv2d_51 (Conv2D)          (None, 10, 10, 10)        4910
#
#  conv2d_52 (Conv2D)          (None, 8, 8, 10)          910
#
#  conv2d_53 (Conv2D)          (None, 8, 8, 10)          110
#
#  conv2d_54 (Conv2D)          (None, 8, 8, 10)          110
#
#  global_average_pooling2d_8   (None, 10)               0
#  (GlobalAveragePooling2D)
#
#  activation_4 (Activation)   (None, 10)                0
#
# ...
# Total params: 11,450
# Trainable params: 11,450
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 1875/1875 [==============================] - 18s 9ms/step - loss: 1.7073 - accuracy: 0.3896
# Epoch 2/5
# ...

# %%
print(keras.optimizers.SGD.__doc__)
# Out:
# Gradient descent (with momentum) optimizer.
#
#   Update rule for parameter `w` with gradient `g` when `momentum` is 0:
#
#   ```python
#   w = w - learning_rate * g
#   ```
#
#   Update rule when `momentum` is larger than 0:
#
#   ```python
#   velocity = momentum * velocity - learning_rate * g
#   w = w + velocity
#   ```
#
#   When `nesterov=True`, this rule becomes:
#
#   ```python
#   velocity = momentum * velocity - learning_rate * g
#   w = w + momentum * velocity - learning_rate * g
#   ```
#
#   Args:
#     learning_rate: A `Tensor`, floating point value, or a schedule that is a
#       `tf.keras.optimizers.schedules.LearningRateSchedule`, or a callable
#       that takes no arguments and returns the actual value to use. The
#       learning rate. Defaults to 0.01.
#     momentum: float hyperparameter >= 0 that accelerates gradient descent
#       in the relevant
#       direction and dampens oscillations. Defaults to 0, i.e., vanilla gradient
#       descent.
# ...
