# %%
import tensorflow as tf
import tensorflow.keras as keras
import datetime

(x_train_images, y_train_labels) , _ = keras.datasets.mnist.load_data() # _ is general throwaway variable. Not wasting characters to save something and dilute visual
x_train_images = x_train_images/255.0
y_train_labels = keras.utils.to_categorical(y_train_labels,10)

# %%
log_dir = "logs/train-" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
vis_callback = keras.callbacks.TensorBoard(log_dir, histogram_freq=1)

model = keras.models.Sequential([
    keras.layers.Input(shape=(28,28)),
    keras.layers.Flatten(),
    keras.layers.Dense(15,activation="relu", use_bias=False),
    keras.layers.Dense(10,activation="softmax", use_bias=False),
])
model.compile(
    loss = "categorical_crossentropy",
    optimizer= "sgd",
    metrics = ['accuracy'],
)
model.build(input_shape=(784))
print(model.summary())
model.fit(x_train_images, y_train_labels, epochs = 20, callbacks = [vis_callback])
# Out:
# Model: "sequential_41"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_37 (Flatten)        (None, 784)               0
#
#  dense_76 (Dense)            (None, 15)                11760
#
#  dense_77 (Dense)            (None, 10)                150
#
# =================================================================
# Total params: 11,910
# Trainable params: 11,910
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 1875/1875 [==============================] - 1s 434us/step - loss: 0.8372 - accuracy: 0.7708
# Epoch 2/20
# 1875/1875 [==============================] - 1s 423us/step - loss: 0.3758 - accuracy: 0.8965
# Epoch 3/20
# 1875/1875 [==============================] - 1s 428us/step - loss: 0.3274 - accuracy: 0.9069
# Epoch 4/20
# 1875/1875 [==============================] - 1s 430us/step - loss: 0.3025 - accuracy: 0.9141
# Epoch 5/20
# 1875/1875 [==============================] - 1s 415us/step - loss: 0.2849 - accuracy: 0.9192
# Epoch 6/20
# 1875/1875 [==============================] - 1s 414us/step - loss: 0.2705 - accuracy: 0.9233
# Epoch 7/20
# 1875/1875 [==============================] - 1s 414us/step - loss: 0.2589 - accuracy: 0.9273
# Epoch 8/20
# 1875/1875 [==============================] - 1s 425us/step - loss: 0.2485 - accuracy: 0.9302
# Epoch 9/20
# 1875/1875 [==============================] - 1s 419us/step - loss: 0.2393 - accuracy: 0.9320
# Epoch 10/20
# 1875/1875 [==============================] - 1s 412us/step - loss: 0.2313 - accuracy: 0.9343
# Epoch 11/20
# 1875/1875 [==============================] - 1s 412us/step - loss: 0.2240 - accuracy: 0.9370
# Epoch 12/20
# 1875/1875 [==============================] - 1s 423us/step - loss: 0.2177 - accuracy: 0.9388
# Epoch 13/20
# 1875/1875 [==============================] - 1s 417us/step - loss: 0.2120 - accuracy: 0.9395
# Epoch 14/20
# 1875/1875 [==============================] - 1s 421us/step - loss: 0.2069 - accuracy: 0.9416
# Epoch 15/20
# 1875/1875 [==============================] - 1s 574us/step - loss: 0.2022 - accuracy: 0.9425
# Epoch 16/20
# 1875/1875 [==============================] - 1s 419us/step - loss: 0.1982 - accuracy: 0.9437
# Epoch 17/20
# 1875/1875 [==============================] - 1s 454us/step - loss: 0.1943 - accuracy: 0.9447
# Epoch 18/20
# 1875/1875 [==============================] - 1s 755us/step - loss: 0.1906 - accuracy: 0.9457
# Epoch 19/20
# 1875/1875 [==============================] - 1s 470us/step - loss: 0.1872 - accuracy: 0.9467
# Epoch 20/20
# 1875/1875 [==============================] - 1s 428us/step - loss: 0.1841 - accuracy: 0.9474

# %%
log_dir = "logs/train-" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
vis_callback = keras.callbacks.TensorBoard(log_dir, histogram_freq=1)

model = keras.models.Sequential([
    keras.layers.Input(shape=(28,28,1)),
    keras.layers.Conv2D(5,7,activation="relu"),
    keras.layers.Conv2D(10,7,activation= "relu"),
    keras.layers.Conv2D(15,7,activation= "relu"),
    keras.layers.Conv2D(25,7,activation= "relu"),
    keras.layers.Conv2D(10,1,activation="relu"),
    keras.layers.Conv2D(10*15,3,activation="relu"),
    keras.layers.Conv2D(10,1,activation="relu"),
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dense(10,activation="softmax", use_bias=False),
])
model.compile(
    loss = "categorical_crossentropy",
    optimizer= "sgd",
    metrics = ['accuracy'],
)
model.build(input_shape=(784))
print(model.summary())
model.fit(x_train_images, y_train_labels, epochs = 20, callbacks = [vis_callback])
# Out:
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_23 (Conv2D)          (None, 22, 22, 5)         250
#
#  conv2d_24 (Conv2D)          (None, 16, 16, 10)        2460
#
#  conv2d_25 (Conv2D)          (None, 10, 10, 15)        7365
#
#  conv2d_26 (Conv2D)          (None, 4, 4, 25)          18400
#
#  conv2d_27 (Conv2D)          (None, 4, 4, 10)          260
#
#  conv2d_28 (Conv2D)          (None, 2, 2, 150)         13650
#
#  conv2d_29 (Conv2D)          (None, 2, 2, 10)          1510
#
#  global_average_pooling2d_3   (None, 10)               0
#  (GlobalAveragePooling2D)
#
#  dense_78 (Dense)            (None, 10)                100
#
# =================================================================
# Total params: 43,995
# Trainable params: 43,995
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 1875/1875 [==============================] - 17s 9ms/step - loss: 1.5072 - accuracy: 0.4620
# Epoch 2/20
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.2564 - accuracy: 0.9224
# Epoch 3/20
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.1443 - accuracy: 0.9561
# Epoch 4/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.1063 - accuracy: 0.9682
# Epoch 5/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0863 - accuracy: 0.9738
# Epoch 6/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0749 - accuracy: 0.9774
# Epoch 7/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0674 - accuracy: 0.9791
# Epoch 8/20
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0622 - accuracy: 0.9811
# Epoch 9/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0574 - accuracy: 0.9828
# Epoch 10/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0533 - accuracy: 0.9841
# Epoch 11/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0497 - accuracy: 0.9851
# Epoch 12/20
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.0460 - accuracy: 0.9861
# Epoch 13/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0420 - accuracy: 0.9876
# Epoch 14/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0411 - accuracy: 0.9879
# Epoch 15/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0388 - accuracy: 0.9880
# Epoch 16/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0375 - accuracy: 0.9886
# Epoch 17/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0346 - accuracy: 0.9893
# Epoch 18/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0337 - accuracy: 0.9894
# Epoch 19/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0318 - accuracy: 0.9895
# Epoch 20/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0304 - accuracy: 0.9905
